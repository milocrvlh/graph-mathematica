# %%
import networkx as nx

G = nx.read_gml("/home/pc/Área de trabalho/Repositórios do Github/graph-mathematica/atividade_2/lesmis.gml")

# %% [markdown]
# Checar se o grafo tem menos de 200 nós:

# %%
G.number_of_nodes()
# Out:
# 77

# %%
nx.draw(G, node_size = 75, with_labels=True, font_size=8)

# %%
G.number_of_nodes()
# Out:
# 77

# %%
G.number_of_edges()
# Out:
# 254
